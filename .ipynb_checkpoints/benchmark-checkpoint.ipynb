# %%
import pandas as pd
# Out:
# /home/ubuntu/.local/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.concat([pd.read_csv('tgi/bench-default.csv'), 
           pd.read_csv('tgi/bench-quantize-bb.csv')])

# %%
df
# Out:
#    tok_count       time                                           question  \
# 0       1000  22.512243  Write a Rust function that performs binary exp...
# 1       1000  22.562057  What are the differences between Javascript an...
# 2       1000  22.812512  Write a story in the style of James Joyce abou...
# 3       1000  22.779474                Who does Harry turn into a balloon?
# 4       1000  22.792701  Write a tale about a time-traveling historian ...
# 5       1000  22.592911                    What is the product of 9 and 8?
# 6       1000  22.800602  If a train travels 120 kilometers in 2 hours, ...
# 7       1000  22.879922  Think through this step by step. If the sequen...
# 0       1000  67.455383  Write a Rust function that performs binary exp...
# 1       1000  68.850923  What are the differences between Javascript an...
# 2       1000  71.218518  Write a story in the style of James Joyce abou...
# ...

# %%
df.groupby('note').mean('time')
# Out:
#                                               tok_count       time
# note
# TGI with bits and bytes quantization             1000.0  68.937669
# TGI with default options and no quantization     1000.0  22.716553

# %% [markdown]
# Why is quantization slower for `bits and bytes`?  Someone else [mentioned it here](https://github.com/huggingface/text-generation-inference/issues/309) and says that it is well known that it is slow!
#
# **Next step: try [thebloke's gptq stuff](https://twitter.com/joao_gante/status/1681593617406906368?s=20)**
